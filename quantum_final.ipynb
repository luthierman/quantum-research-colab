# %% [markdown]
# <a href="https://colab.research.google.com/github/luthierman/quantum-research/blob/main/quantum_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
import os.path

# %% [markdown]
# CARTPOLE

# %%
c_cartpole = "/content/drive/MyDrive/quantum_research/cart_pole/classical_models/"
c_cartpole_models = ["CDQN-2021-04-26_58_ADAM_lr0.003_g0.95_eps1.0_epsmin0.01_epsd0.9",
                     "CDQN-2021-04-26_226_ADAM_lr0.003_g0.95_eps1.0_epsmin0.01_epsd0.9",
                     "CDQN-2021-04-26_1282_ADAM_lr0.003_g0.95_eps1.0_epsmin0.01_epsd0.9"
                      ]
q_cartpole = "/content/drive/MyDrive/quantum_research/cart_pole/quantum_models/"
q_cartpole_models = ["200+QDQN-2021-04-26_qbits4_ADAM_lr0.01_bs_32_g0.95_eps1.0_epsmin0.01_epsd0.9",
                     "200+QDQN-2021-04-26_qbits8_ADAM_lr0.01_bs_32_g0.95_eps1.0_epsmin0.01_epsd0.9",
                     "200+QDQN-2021-04-26_qbits12_ADAM_lr0.01_bs_32_g0.95_eps1.0_epsmin0.01_epsd0.9",
                    "QDQN-2021-04-26_qbits4_ADAM_lr0.01_g0.95_eps1.0_epsmin0.01_epsd0.9",
                    "QDQN-2021-04-26_qbits8_ADAM_lr0.01_g0.95_eps1.0_epsmin0.01_epsd0.9",
                     "QDQN-2021-04-26_qbits12_ADAM_lr0.01_g0.95_eps1.0_epsmin0.01_epsd0.9"
                     ]

c1000_58r = np.load(c_cartpole+c_cartpole_models[0]+"/"+"rewards.npy")
c1000_58ar = np.load(c_cartpole+c_cartpole_models[0]+"/"+"averages.npy")
c1000_58l = np.load(c_cartpole+c_cartpole_models[0]+"/"+"loss.npy")
c1000_58t = np.load(c_cartpole+c_cartpole_models[0]+"/"+"times.npy")

c1000_226r = np.load(c_cartpole+c_cartpole_models[1]+"/"+"rewards.npy")
c1000_226ar = np.load(c_cartpole+c_cartpole_models[1]+"/"+"averages.npy")
c1000_226l = np.load(c_cartpole+c_cartpole_models[1]+"/"+"loss.npy")
c1000_226t = np.load(c_cartpole+c_cartpole_models[1]+"/"+"times.npy")


c1000_1282r = np.load(c_cartpole+c_cartpole_models[2]+"/"+"rewards.npy")
c1000_1282ar = np.load(c_cartpole+c_cartpole_models[2]+"/"+"averages.npy")
c1000_1282l = np.load(c_cartpole+c_cartpole_models[2]+"/"+"loss.npy")
c1000_1282t = np.load(c_cartpole+c_cartpole_models[2]+"/"+"times.npy")

q200_4r = np.load(q_cartpole+q_cartpole_models[0]+"/"+"rewards.npy")
q200_4ar = np.load(q_cartpole+q_cartpole_models[0]+"/"+"averages.npy")
q200_4l = np.load(q_cartpole+q_cartpole_models[0]+"/"+"loss.npy")
q200_4t = np.load(q_cartpole+q_cartpole_models[0]+"/"+"times.npy")

q200_8r = np.load(q_cartpole+q_cartpole_models[1]+"/"+"rewards.npy")
q200_8ar = np.load(q_cartpole+q_cartpole_models[1]+"/"+"averages.npy")
q200_8l = np.load(q_cartpole+q_cartpole_models[1]+"/"+"loss.npy")
q200_8t = np.load(q_cartpole+q_cartpole_models[1]+"/"+"times.npy")

q200_12r = np.load(q_cartpole+q_cartpole_models[2]+"/"+"rewards.npy")
q200_12ar = np.load(q_cartpole+q_cartpole_models[2]+"/"+"averages.npy")
q200_12l = np.load(q_cartpole+q_cartpole_models[2]+"/"+"loss.npy")
q200_12t = np.load(q_cartpole+q_cartpole_models[2]+"/"+"times.npy")

q1000_4r = np.load(q_cartpole+q_cartpole_models[3]+"/"+"rewards.npy")
q1000_4ar = np.load(q_cartpole+q_cartpole_models[3]+"/"+"averages.npy")
q1000_4l = np.load(q_cartpole+q_cartpole_models[3]+"/"+"loss.npy")
q1000_4t = np.load(q_cartpole+q_cartpole_models[3]+"/"+"times.npy")

q1000_8r = np.load(q_cartpole+q_cartpole_models[4]+"/"+"rewards.npy")
q1000_8ar = np.load(q_cartpole+q_cartpole_models[4]+"/"+"averages.npy")
q1000_8l = np.load(q_cartpole+q_cartpole_models[4]+"/"+"loss.npy")
q1000_8t = np.load(q_cartpole+q_cartpole_models[4]+"/"+"times.npy")

q1000_12r = np.load(q_cartpole+q_cartpole_models[5]+"/"+"rewards.npy")
q1000_12ar = np.load(q_cartpole+q_cartpole_models[5]+"/"+"averages.npy")
q1000_12l = np.load(q_cartpole+q_cartpole_models[5]+"/"+"loss.npy")
q1000_12t = np.load(q_cartpole+q_cartpole_models[5]+"/"+"times.npy")

# %%
# plt.ylim(0,200)
# plt.plot(q1000_12r, color='red', alpha = .2, label='Reward')
plt.plot(q200_12l, color='red', label='QVC 12 qubits')
# plt.plot(q1000_8r, color='blue', alpha = .2, label='Reward')
plt.plot(q200_8l, color='blue', label='QVC 8 qubits')
# plt.plot(q1000_4r, color='purple', alpha = .2, label='Reward')
plt.plot(q200_4l, color='purple', label='QVC 4 qubits')
plt.legend()
plt.title("Avg. Reward for DQN per Episode (CartPole)")
plt.ylabel('Reward')
plt.xlabel('Iteration')
plt.show()

# %%
# plt.ylim(0,200)
plt.plot(c1000_1282l[:200], color = "blue", label = "10^3 NN")
plt.plot(c1000_226l[:200], color = "red", label = "10^2 NN")
plt.plot(c1000_58l[:200], color = "purple", label = "10^1 NN")
plt.legend()
plt.title("Avg. Reward for DQN per Episode (CartPole)")
plt.ylabel('Reward')
plt.xlabel('Iteraction')
plt.show()

# %%
plt.ylim(0,200)
# plt.plot(q1000_12ar, color='red', label='QVC 12 Qubits')
plt.plot(q200_4ar, color='red', label='QVC 8 Qubits')
# plt.plot(q1000_4ar, color='red', label='QVC 4 Qubits')
plt.plot(c1000_1282ar[:200], color = "blue", label = "10^3 NN")
plt.plot(c1000_226ar[:200], color = "blue", label = "10^2 NN")
plt.plot(c1000_58ar[:200], color = "blue", label = "10^1 NN")
plt.legend()
plt.title("Avg. Reward for DQN per Episode (CartPole)")
plt.ylabel('Average Reward')
plt.xlabel('Iteration')
plt.show()

# %%
# plt.plot(q1000_12r, color='red', alpha = .2, label='Reward')
plt.plot(q200_12l, color='red', label='QVC 12 qubits')
plt.plot(q200_8l, color='red', label='QVC 8 qubits')
plt.plot(q200_4l, color='red', label='QVC 4 qubits')
plt.plot(c1000_1282l[:200], color = "blue", label = "10^3 NN")
plt.plot(c1000_226l[:200], color = "blue", label = "10^2 NN")
plt.plot(c1000_58l[:200], color = "blue", label = "10^1 NN")
plt.legend()
plt.ylabel("Average Loss")
plt.xlabel('Iteration')
plt.title("Avg. MSBE for DQN per Episode (CartPole)")
plt.show()

# %%
plt.ylim(0,200)
# plt.plot(q1000_12ar, color='red', label='QVC 12 Qubits')
# plt.plot(q1000_8ar, color='red', label='QVC 8 Qubits')
# plt.plot(q1000_4ar, color='red', label='QVC 4 Qubits')
plt.plot(c1000_1282ar, color = "purple", label = "10^3 NN")
plt.plot(c1000_226ar, color = "red", label = "10^2 NN")
plt.plot(c1000_58ar, color = "blue", label = "10^1 NN")
plt.title("Avg. Reward and MSBE for DQN per Episode (CartPole)")
plt.ylabel('Average Reward')
plt.legend()
plt.twinx()
plt.ylim(0,4)
plt.plot(c1000_1282l, color = "purple", alpha=.2,label = "10^3 NN")
plt.plot(c1000_226l, color = "red", alpha=.2,label = "10^2 NN")
plt.plot(c1000_58l, color = "blue", alpha=.2,label = "10^1 NN")
plt.ylabel('Average Loss')

plt.xlabel('Iteration')
plt.show()

# %%
# plt.plot(q1000_12r, color='red', alpha = .2, label='Reward')
# plt.plot(q1000_12t, color='orange', label='QVC 12 qubits')
# plt.plot(q1000_8t, color='pink', label='QVC 8 qubits')
# plt.plot(q1000_4t, color='green', label='QVC 4 qubits')
plt.plot(c1000_1282t, color = "purple", label = "10^3 NN")
plt.plot(c1000_226t, color = "red", label = "10^2 NN")
plt.plot(c1000_58t, color = "blue", label = "10^1 NN")
plt.legend()
plt.ylabel("Processing Time (seconds)")
plt.xlabel('Iteration')
plt.title("Processing Time for DQN per Episode (CartPole)")
plt.show()

# %% [markdown]
# BLACKJACK

# %%
blackjack = "/content/drive/MyDrive/quantum_research/black_jack/"
c_blackjack = blackjack+"classical_models/"
c_blackjack_models = ["CDQN-2021-04-26_50_ADAM_lr0.003_bs32_g0.95_eps1.0_epsmin0.01_epsd0.9",
                     "CDQN-2021-04-26_194_ADAM_lr0.003_bs32_g0.95_eps1.0_epsmin0.01_epsd0.9",
                     "CDQN-2021-04-26_1250_ADAM_lr0.003_bs32_g0.95_eps1.0_epsmin0.01_epsd0.9"
                      ]
q_blackjack = blackjack+"quantum_models/"
q_blackjack_models = [
                       "200+QDQN-2021-04-26_qbits4_ADAM_lr0.01_bs32_g0.95_eps1.0_epsmin0.01_epsd0.9",
                      "200+QDQN-2021-04-26_qbits8_ADAM_lr0.01_bs32_g0.95_eps1.0_epsmin0.01_epsd0.9",
                      "200+QDQN-2021-04-26_qbits12_ADAM_lr0.01_bs32_g0.95_eps1.0_epsmin0.01_epsd0.9"
                  
                     ]

c_50r = np.load(c_blackjack+c_blackjack_models[0]+"/"+"rewards.npy")
c_50ar = np.load(c_blackjack+c_blackjack_models[0]+"/"+"averages.npy")
c_50l = np.load(c_blackjack+c_blackjack_models[0]+"/"+"loss.npy")
c_50t = np.load(c_blackjack+c_blackjack_models[0]+"/"+"times.npy")

c_194r = np.load(c_blackjack+c_blackjack_models[1]+"/"+"rewards.npy")
c_194ar = np.load(c_blackjack+c_blackjack_models[1]+"/"+"averages.npy")
c_194l = np.load(c_blackjack+c_blackjack_models[1]+"/"+"loss.npy")
c_194t = np.load(c_blackjack+c_blackjack_models[1]+"/"+"times.npy")


c_1250r = np.load(c_blackjack+c_blackjack_models[2]+"/"+"rewards.npy")
c_1250ar = np.load(c_blackjack+c_blackjack_models[2]+"/"+"averages.npy")
c_1250l = np.load(c_blackjack+c_blackjack_models[2]+"/"+"loss.npy")
c_1250t = np.load(c_blackjack+c_blackjack_models[2]+"/"+"times.npy")

q_4r = np.load(q_blackjack+q_blackjack_models[0]+"/"+"rewards.npy")
q_4ar = np.load(q_blackjack+q_blackjack_models[0]+"/"+"averages.npy")
q_4l = np.load(q_blackjack+q_blackjack_models[0]+"/"+"loss.npy")
q_4t = np.load(q_blackjack+q_blackjack_models[0]+"/"+"times.npy")

q_8r = np.load(q_blackjack+q_blackjack_models[1]+"/"+"rewards.npy")
q_8ar = np.load(q_blackjack+q_blackjack_models[1]+"/"+"averages.npy")
q_8l = np.load(q_blackjack+q_blackjack_models[1]+"/"+"loss.npy")
q_8t = np.load(q_blackjack+q_blackjack_models[1]+"/"+"times.npy")

q_12r = np.load(q_blackjack+q_blackjack_models[2]+"/"+"rewards.npy")
q_12ar = np.load(q_blackjack+q_blackjack_models[2]+"/"+"averages.npy")
q_12l = np.load(q_blackjack+q_blackjack_models[2]+"/"+"loss.npy")
q_12t = np.load(q_blackjack+q_blackjack_models[2]+"/"+"times.npy")

# %%
plt.ylim(-1,1)
plt.plot(q_12ar, color='orange', label='QVC 12 qubits')
plt.plot(q_8ar, color='pink', label='QVC 8 qubits')
plt.plot(q_4ar, color='green', label='QVC 4 qubits')
plt.plot(c_1250ar, color = "purple", label = "10^3 NN")
plt.plot(c_194ar, color = "red", label = "10^2 NN")
plt.plot(c_50ar, color = "blue", label = "10^1 NN")
plt.legend()
plt.title("Avg. Reward for DQN per Episode (BlackJack)")
plt.ylabel('Reward')
plt.xlabel('Iteration')
plt.show()

# %%
plt.ylim(-1,1)

plt.plot(c_1250ar, color = "purple", label = "10^3 NN")
plt.plot(c_194ar, color = "red", label = "10^2 NN")
plt.plot(c_50ar, color = "blue", label = "10^1 NN")
plt.ylabel('Reward')
plt.legend()
plt.twinx()
plt.ylim(0,4)
plt.plot(c_1250l, color = "purple", alpha=.2,label = "10^3 NN")
plt.plot(c_194l, color = "red", alpha=.2,label = "10^2 NN")
plt.plot(c_50l, color = "blue", alpha = .2,label = "10^1 NN")
plt.ylabel("Loss")
plt.title("Avg. Reward and MSBE for DQN per Episode (BlackJack)")

plt.xlabel('Iteration')
plt.show()

# %%
plt.ylim(-1,1)

plt.plot(q_12ar, color = "purple", label='QVC 12 qubits')
plt.plot(q_8ar, color = "red", label='QVC 8 qubits')
plt.plot(q_4ar, color = "blue", label='QVC 4 qubits')
plt.legend()
plt.ylabel('Reward')
plt.twinx()
plt.ylim(0,4)
plt.plot(q_12l, color = "purple", alpha=.2,label='QVC 12 qubits')
plt.plot(q_8l, color = "red", alpha=.2,label='QVC 8 qubits')
plt.plot(q_4l, color = "blue", alpha=.2,label='QVC 4 qubits')
plt.ylabel("Loss")

plt.title("Avg. Reward and MSBE for DQN per Episode (BlackJack)")

plt.xlabel('Iteration')
plt.show()

# %%
plt.ylim(-1,1)
plt.plot(q_12ar, color='red', label='QVC 12 qubits')
plt.plot(q_8ar, color='red', label='QVC 8 qubits')
plt.plot(q_4ar, color='red', label='QVC 4 qubits')
plt.plot(c_1250ar, color = "blue", label = "10^3 NN")
plt.plot(c_194ar, color = "blue", label = "10^2 NN")
plt.plot(c_50ar, color = "blue", label = "10^1 NN")
plt.legend()
plt.title("Avg. Reward for DQN per Episode (BlackJack)")
plt.ylabel('Reward')
plt.xlabel('Iteration')
plt.show()

# %%
plt.ylim(0,4)
plt.plot(q_12l, color='purple', label='QVC 12 qubits')
plt.plot(q_8l, color='red', label='QVC 8 qubits')
plt.plot(q_4l, color='blue', label='QVC 4 qubits')
# plt.plot(c_1250l, color = "purple", label = "10^3 NN")
# plt.plot(c_194l, color = "red", label = "10^2 NN")
# plt.plot(c_50l, color = "blue", label = "10^1 NN")
plt.legend()
plt.title("Avg. MSBE for DQN per Episode (BlackJack)")
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.show()

# %%
# plt.plot(q_12t, color='orange', label='QVC 12 qubits')
# plt.plot(q_8t, color='pink', label='QVC 8 qubits')
# plt.plot(q_4t, color='green', label='QVC 4 qubits')
plt.plot(c_1250t, color = "purple", label = "10^3 NN")
plt.plot(c_194t, color = "red", label = "10^2 NN")
plt.plot(c_50t, color = "blue", label = "10^1 NN")
plt.legend()
plt.title("Processing Time for DQN per Episode (BlackJack)")
plt.ylabel('Processing Time (seconds)')
plt.xlabel('Iteration')
plt.show()
